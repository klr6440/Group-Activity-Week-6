# %%
import pandas as pd;

# %%
pd.read_excel("Dataset_w6.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-1cb4d56cfb20> in <module>
# ----> 1 pd.read_excel("Dataset_w6.xls")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# ...

# %%
international_affairs = pd.read_excel("Dataset_w6.xls")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6748b69c4870> in <module>
# ----> 1 international_affairs = pd.read_excel("Dataset_w6.xls")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
international_affairs = pd.read_excel("Dataset_w6.xlsx")

# %%
international_affairs
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %%
international_affairs.nunique()
# Out:
# country                                       196
# Region                                         22
# Surface area (km2)                            196
# Population in thousands (2017)                192
# GDP per capita (current US$)                  195
# Agricultural production index                  82
# International trade: Imports (million US$)    195
# dtype: int64

# %%
international_affairs['country'].value_counts()
# Out:
# Equatorial Guinea                   1
# Iraq                                1
# Spain                               1
# Democratic Republic of the Congo    1
# Ukraine                             1
#                                    ..
# Cook Islands                        1
# Comoros                             1
# Serbia                              1
# Libya                               1
# Nigeria                             1
# Name: country, Length: 196, dtype: int64

# %% [raw]
# new_frame = international_affairs[['country']]

# %%
new_frame = international_affairs[['country','Region']]

# %%
new_frame.nunique()
# Out:
# country    196
# Region      22
# dtype: int64

# %%
new_frame.nunique()
# Out:
# country    196
# dtype: int64

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

# %%
international_affairs.sort_values(by = ['GDP per capita (current US$)']).head(5)
# Out:
#                       country         Region  Surface area (km2)  \
# 161                   Somalia  EasternAfrica              637657
# 28                    Burundi  EasternAfrica               27830
# 34   Central African Republic   MiddleAfrica              622984
# 128                     Niger  WesternAfrica             1267000
# 106                    Malawi  EasternAfrica              118484
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 161                           14742                         144.5
# 28                            10864                         244.6
# 34                             4659                         333.2
# 128                           21477                         359.0
# 106                           18622                         372.9
#
#      Agricultural production index   \
# 161                             112
# 28                              109
# 34                              114
# ...

# %%
new_frame = international_affairs[['country','Region']]

# %%
new_frame
# Out:
#                                 country             Region
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
# [196 rows x 2 columns]

# %%
new_frame.groupby(new_frame['Region']).count().country
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %%
international_affairs.mean("GDP per capita (current US$)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 'GDP per capita (current US$)'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-bafa0926a721> in <module>
# ----> 1 international_affairs.mean("GDP per capita (current US$)")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
# ...

# %%
import statistics

# %%
international_affairs.mean("GDP per capita (current US$)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 'GDP per capita (current US$)'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-bafa0926a721> in <module>
# ----> 1 international_affairs.mean("GDP per capita (current US$)")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
# ...

# %%
international_affairs.mean(GDP per capita (current US$))
# Out:
#   File "<ipython-input-40-4f92556edb77>", line 1
#     international_affairs.mean(GDP per capita (current US$))
#                                    ^
# SyntaxError: invalid syntax

# %%
new_frame = international_affairs[['Region','GDP per capita (current US$)','International trade: Imports (million US$)']]

# %%
new_frame
# Out:
#                 Region  GDP per capita (current US$)  \
# 0         SouthernAsia                         623.2
# 1       SouthernEurope                        3984.2
# 2       NorthernAfrica                        4154.1
# 3         MiddleAfrica                        4714.1
# 4            Caribbean                       14764.5
# ..                 ...                           ...
# 191       SouthAmerica                       11068.9
# 192  South-easternAsia                        2067.9
# 193        WesternAsia                        1106.4
# 194      EasternAfrica                        1311.1
# 195      EasternAfrica                         890.4
#
#      International trade: Imports (million US$)
# 0                                          3568
# 1                                          4669
# 2                                         47091
# 3                                          8790
# 4                                           491
# ...

# %%
new_frame
# Out:
#                 Region  GDP per capita (current US$)
# 0         SouthernAsia                         623.2
# 1       SouthernEurope                        3984.2
# 2       NorthernAfrica                        4154.1
# 3         MiddleAfrica                        4714.1
# 4            Caribbean                       14764.5
# ..                 ...                           ...
# 191       SouthAmerica                       11068.9
# 192  South-easternAsia                        2067.9
# 193        WesternAsia                        1106.4
# 194      EasternAfrica                        1311.1
# 195      EasternAfrica                         890.4
#
# [196 rows x 2 columns]

# %%
new_frame.groupby(new_frame['Region','GDP per capita (current US$)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Region', 'GDP per capita (current US$)')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-ea689ea2ae7e> in <module>
# ...

# %%
new_frame
# Out:
#                 Region  GDP per capita (current US$)
# 0         SouthernAsia                         623.2
# 1       SouthernEurope                        3984.2
# 2       NorthernAfrica                        4154.1
# 3         MiddleAfrica                        4714.1
# 4            Caribbean                       14764.5
# ..                 ...                           ...
# 191       SouthAmerica                       11068.9
# 192  South-easternAsia                        2067.9
# 193        WesternAsia                        1106.4
# 194      EasternAfrica                        1311.1
# 195      EasternAfrica                         890.4
#
# [196 rows x 2 columns]

# %%
new_frame.groupby(new_frame['Region']).mean().GDP per capita (current US$)
# Out:
#   File "<ipython-input-53-eb8556ffdcf9>", line 1
#     new_frame.groupby(new_frame['Region']).mean().GDP per capita (current US$)
#                                                       ^
# SyntaxError: invalid syntax

# %%
new_frame["GDP per capita (current US$)"].mean()
# Out:
# 13727.343367346926

# %%
gdp = new_frame.groupby(new_frame['Region'])["GDP per capita (current US$)"].mean().to_frame()

# %%
gdp
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                          15135.562500
# CentralAmerica                      6348.137500
# CentralAsia                         4329.880000
# EasternAfrica                       2088.852941
# EasternAsia                        27967.614286
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Micronesia                          5008.300000
# MiddleAfrica                        3928.833333
# NorthernAfrica                      3934.960000
# NorthernAmerica                    57659.000000
# NorthernEurope                     42098.220000
# Oceania                            44823.250000
# Polynesia                           8686.520000
# South-easternAsia                  10299.027273
# SouthAmerica                        8499.775000
# SouthernAfrica                      4191.900000
# SouthernAsia                        2968.400000
# ...

# %%
gdp.sort_values(by = ['GDP per capita (current US$)'],ascending=False).head(5)
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                  57659.000000
# WesternEurope                    55387.128571
# Oceania                          44823.250000
# NorthernEurope                   42098.220000
# EasternAsia                      27967.614286

# %%
int_trade = new_frame.groupby(new_frame['Region'])["International trade: Imports (million US$)"].mean().to_frame()

# %%
int_trade
# Out:
#                    International trade: Imports (million US$)
# Region
# Caribbean                                         3057.312500
# CentralAmerica                                   57031.500000
# CentralAsia                                      12063.400000
# EasternAfrica                                     4726.176471
# EasternAsia                                     451995.000000
# EasternEurope                                    85243.900000
# Melanesia                                         2896.400000
# Micronesia                                          99.000000
# MiddleAfrica                                      4381.222222
# NorthernAfrica                                   35034.400000
# NorthernAmerica                                 663552.250000
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# Polynesia                                          432.000000
# ...

# %% [raw]
# int_trade.sort_values(by = ['International trade: Imports (million US$)'],ascending=False).head(5)

# %%
int_trade.sort_values(by = ['International trade: Imports (million US$)'],ascending=False).head(5)
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                               663552.250000
# EasternAsia                                   451995.000000
# WesternEurope                                 407498.428571
# NorthernEurope                                113407.200000
# Oceania                                       112914.500000
